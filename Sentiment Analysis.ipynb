# %%
import torch

# %%
camembert = torch.hub.load('pytorch/fairseq', 'camembert.v0')
# Out:
# Using cache found in C:\Users\lsedu/.cache\torch\hub\pytorch_fairseq_master
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/.cache\torch\hub\pytorch_fairseq_master/hubconf.py in <module>
#      23 try:
# ---> 24     import fairseq.data.token_block_utils_fast
#      25 except (ImportError, ModuleNotFoundError):
#
# ModuleNotFoundError: No module named 'fairseq.data.token_block_utils_fast'
#
# During handling of the above exception, another exception occurred:
#
# DistutilsClassError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\setuptools\sandbox.py in save_modules()
#     153     with ExceptionSaver() as saved_exc:
# --> 154         yield saved
#     155
#
# ~\anaconda3\lib\site-packages\setuptools\sandbox.py in setup_context(setup_dir)
#     194                             __import__('setuptools')
# ...
